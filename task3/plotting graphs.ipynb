# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from numpy import genfromtxt
data_11= genfromtxt('csvs/run_logs-cifar10_task11-tag-accuracy.csv', delimiter=',')
data_12 = genfromtxt('csvs/run_logs-cifar10_task12-tag-accuracy.csv', delimiter=',')[0::2,:]
data_13 = genfromtxt('csvs/run_logs-cifar10_task13-tag-accuracy.csv', delimiter=',')[0::2,:]
data_14 = genfromtxt('csvs/run_logs-cifar10_task14-tag-accuracy.csv', delimiter=',')

# %%
plt.plot(data_11[1:,1], np.array([data_11[1:,2], data_12[1:,2], data_13[1:,2], data_14[1:,2]]).T)
plt.legend(['no augmentation' ,'normalized', 'flipping', 'cropping'])
plt.xlabel('iterations')
plt.ylabel('training accuracy')
plt.savefig('graphs/task1.eps')

# %%
#np.c_[data_11[1:,2], data_12[1:,2], data_13[1:,2], data_14[1:,2]]
print(data_11[1:,2].shape, data_12[1::,2].shape, data_13[1::,2].shape, data_14[1:,2].shape)
#data_12
# Out:
# (20,) (20,) (20,) (20,)

# %%
data_11= genfromtxt('csvs/run_logs-cifar10_task21-tag-accuracy.csv', delimiter=',')
data_12 = genfromtxt('csvs/run_logs-cifar10_task23-tag-accuracy.csv', delimiter=',')[0::,:]
data_13 = genfromtxt('csvs/run_logs-cifar10_task24-tag-accuracy.csv', delimiter=',')[0::,:]
data_14 = genfromtxt('csvs/run_logs-cifar10_fractalnet-tag-accuracy.csv', delimiter=',')

# %%
plt.plot(data_11[1:,1], np.array([data_11[1:,2], data_12[1:,2], data_13[1:,2], data_14[1:,2]]).T)
plt.legend(['AllConv' ,'+20', 'ResNet', 'FractalNet'])
plt.xlabel('iterations')
plt.ylabel('training accuracy')
plt.savefig('graphs/train2.eps')

# %%
data_11= genfromtxt('csvs/run_logs-cifar10_task21-tag-conv1_grad.csv', delimiter=',')
data_12 = genfromtxt('csvs/run_logs-cifar10_task23-tag-conv1_grad.csv', delimiter=',')[0::,:]
data_13 = genfromtxt('csvs/run_logs-cifar10_task24-tag-conv1_grad.csv', delimiter=',')[0::,:]
data_14 = genfromtxt('csvs/run_logs-cifar10_fractalnet-tag-conv1_grad.csv', delimiter=',')
plt.plot(data_11[1:,1], np.array([data_11[1:,2], data_12[1:,2], data_13[1:,2], data_14[1:,2]]).T)
plt.legend(['AllConv' ,'+20', 'ResNet', 'FractalNet'])
plt.xlabel('iterations')
plt.ylabel('gradient magnitude')
plt.savefig('graphs/convfirst2.eps')

# %%
data_11= genfromtxt('csvs/run_logs-cifar10_task21-tag-convlast_grad.csv', delimiter=',')
data_12 = genfromtxt('csvs/run_logs-cifar10_task23-tag-convlast_grad.csv', delimiter=',')[0::,:]
data_13 = genfromtxt('csvs/run_logs-cifar10_task24-tag-convlast_grad.csv', delimiter=',')[0::,:]
data_14 = genfromtxt('csvs/run_logs-cifar10_fractalnet-tag-convlast_grad.csv', delimiter=',')
plt.plot(data_11[1:,1], np.array([data_11[1:,2], data_12[1:,2], data_13[1:,2], data_14[1:,2]]).T)
plt.legend(['AllConv' ,'+20', 'ResNet', 'FractalNet'])
plt.xlabel('iterations')
plt.ylabel('gradient magnitude')
plt.savefig('graphs/convlast2.eps')

# %%
x=np.zeros([2,2])
y=x.copy()
y[1,1]=2
np.sign(x+10)
1e-7*1000
np.floor(np.array([0,1,2,3,4,5,6])/2)
np.std()
x+10
# Out:
# array([[ 10.,  10.],
#        [ 10.,  10.]])

# %%
np.array([4, 5, 3, 2, 10]).argsort()
np.linspace(1,10, 10)
np.arange(1,10)
x=(100*np.random.rand(5,5)).astype(int)
print(x)
x[np.arange(0,5),[0, 1, 2, 3, 4]]
# Out:
# [[51 68 97 66 42]
#  [11 92 63 57 40]
#  [99  7 27 30 32]
#  [34 76 55 54 84]
#  [88 29 89 19 75]]
# array([51, 92, 27, 54, 75])
